# %%
import math
import warnings

import torch
import torchinfo
from pandas.errors import SettingWithCopyWarning
from torch import nn
from torch.utils.data import DataLoader
import timm
import glob
import os
import numpy as np
import pandas as pd
from glob import glob
import tqdm
from torch.utils.data import Dataset
import albumentations as A
import pydicom
from single_dataset import DATA_PATH
from single_train import set_random_seed

# %%
SEED = 8620
N_FOLDS = 14

set_random_seed(SEED)

# %%
train_merged = pd.read_csv(DATA_PATH / "temp_train.csv")

# %%
train_merged.loc[(train_merged.plane == "Sagittal T1") & (train_merged.condition == "Spinal Canal Stenosis"), "plane"] = "Sagittal T2/STIR"

# %%
dist = train_merged[["plane", "condition", "level", "instance_number", "label"]].groupby(["plane", "condition", "level", "label"]).count().reset_index()
print(dist.to_string())
# Out:
#                plane                         condition  level        label  instance_number
# 0           Axial T2        Left Subarticular Stenosis  L1/L2     Moderate               93
# 1           Axial T2        Left Subarticular Stenosis  L1/L2  Normal/Mild             1688
# 2           Axial T2        Left Subarticular Stenosis  L1/L2       Severe               28
# 3           Axial T2        Left Subarticular Stenosis  L2/L3     Moderate              254
# 4           Axial T2        Left Subarticular Stenosis  L2/L3  Normal/Mild             1554
# 5           Axial T2        Left Subarticular Stenosis  L2/L3       Severe               83
# 6           Axial T2        Left Subarticular Stenosis  L3/L4     Moderate              454
# 7           Axial T2        Left Subarticular Stenosis  L3/L4  Normal/Mild             1323
# 8           Axial T2        Left Subarticular Stenosis  L3/L4       Severe              193
# 9           Axial T2        Left Subarticular Stenosis  L4/L5     Moderate              624
# 10          Axial T2        Left Subarticular Stenosis  L4/L5  Normal/Mild              885
# 11          Axial T2        Left Subarticular Stenosis  L4/L5       Severe              461
# 12          Axial T2        Left Subarticular Stenosis  L5/S1     Moderate              409
# 13          Axial T2        Left Subarticular Stenosis  L5/S1  Normal/Mild             1407
# 14          Axial T2        Left Subarticular Stenosis  L5/S1       Severe              147
# 15          Axial T2       Right Subarticular Stenosis  L1/L2     Moderate              110
# 16          Axial T2       Right Subarticular Stenosis  L1/L2  Normal/Mild             1678
# 17          Axial T2       Right Subarticular Stenosis  L1/L2       Severe               24
# 18          Axial T2       Right Subarticular Stenosis  L2/L3     Moderate              243
# 19          Axial T2       Right Subarticular Stenosis  L2/L3  Normal/Mild             1576
# 20          Axial T2       Right Subarticular Stenosis  L2/L3       Severe               72
# 21          Axial T2       Right Subarticular Stenosis  L3/L4     Moderate              454
# 22          Axial T2       Right Subarticular Stenosis  L3/L4  Normal/Mild             1321
# 23          Axial T2       Right Subarticular Stenosis  L3/L4       Severe              196
# 24          Axial T2       Right Subarticular Stenosis  L4/L5     Moderate              622
# 25          Axial T2       Right Subarticular Stenosis  L4/L5  Normal/Mild              889
# 26          Axial T2       Right Subarticular Stenosis  L4/L5       Severe              460
# 27          Axial T2       Right Subarticular Stenosis  L5/S1     Moderate              396
# 28          Axial T2       Right Subarticular Stenosis  L5/S1  Normal/Mild             1398
# 29          Axial T2       Right Subarticular Stenosis  L5/S1       Severe              173
# 30       Sagittal T1   Left Neural Foraminal Narrowing  L1/L2     Moderate               63
# 31       Sagittal T1   Left Neural Foraminal Narrowing  L1/L2  Normal/Mild             1907
# 32       Sagittal T1   Left Neural Foraminal Narrowing  L1/L2       Severe                2
# 33       Sagittal T1   Left Neural Foraminal Narrowing  L2/L3     Moderate              171
# 34       Sagittal T1   Left Neural Foraminal Narrowing  L2/L3  Normal/Mild             1791
# 35       Sagittal T1   Left Neural Foraminal Narrowing  L2/L3       Severe               10
# 36       Sagittal T1   Left Neural Foraminal Narrowing  L3/L4     Moderate              410
# 37       Sagittal T1   Left Neural Foraminal Narrowing  L3/L4  Normal/Mild             1522
# 38       Sagittal T1   Left Neural Foraminal Narrowing  L3/L4       Severe               40
# 39       Sagittal T1   Left Neural Foraminal Narrowing  L4/L5     Moderate              628
# 40       Sagittal T1   Left Neural Foraminal Narrowing  L4/L5  Normal/Mild             1204
# 41       Sagittal T1   Left Neural Foraminal Narrowing  L4/L5       Severe              140
# 42       Sagittal T1   Left Neural Foraminal Narrowing  L5/S1     Moderate              520
# 43       Sagittal T1   Left Neural Foraminal Narrowing  L5/S1  Normal/Mild             1247
# 44       Sagittal T1   Left Neural Foraminal Narrowing  L5/S1       Severe              205
# 45       Sagittal T1  Right Neural Foraminal Narrowing  L1/L2     Moderate               63
# 46       Sagittal T1  Right Neural Foraminal Narrowing  L1/L2  Normal/Mild             1890
# 47       Sagittal T1  Right Neural Foraminal Narrowing  L1/L2       Severe               13
# 48       Sagittal T1  Right Neural Foraminal Narrowing  L2/L3     Moderate              167
# 49       Sagittal T1  Right Neural Foraminal Narrowing  L2/L3  Normal/Mild             1793
# 50       Sagittal T1  Right Neural Foraminal Narrowing  L2/L3       Severe                6
# 51       Sagittal T1  Right Neural Foraminal Narrowing  L3/L4     Moderate              414
# 52       Sagittal T1  Right Neural Foraminal Narrowing  L3/L4  Normal/Mild             1512
# 53       Sagittal T1  Right Neural Foraminal Narrowing  L3/L4       Severe               39
# 54       Sagittal T1  Right Neural Foraminal Narrowing  L4/L5     Moderate              628
# 55       Sagittal T1  Right Neural Foraminal Narrowing  L4/L5  Normal/Mild             1208
# 56       Sagittal T1  Right Neural Foraminal Narrowing  L4/L5       Severe              130
# 57       Sagittal T1  Right Neural Foraminal Narrowing  L5/S1     Moderate              495
# 58       Sagittal T1  Right Neural Foraminal Narrowing  L5/S1  Normal/Mild             1281
# 59       Sagittal T1  Right Neural Foraminal Narrowing  L5/S1       Severe              190
# 60  Sagittal T2/STIR             Spinal Canal Stenosis  L1/L2     Moderate               65
# 61  Sagittal T2/STIR             Spinal Canal Stenosis  L1/L2  Normal/Mild             1818
# 62  Sagittal T2/STIR             Spinal Canal Stenosis  L1/L2       Severe               21
# 63  Sagittal T2/STIR             Spinal Canal Stenosis  L2/L3     Moderate              149
# 64  Sagittal T2/STIR             Spinal Canal Stenosis  L2/L3  Normal/Mild             1732
# 65  Sagittal T2/STIR             Spinal Canal Stenosis  L2/L3       Severe               53
# 66  Sagittal T2/STIR             Spinal Canal Stenosis  L3/L4     Moderate              230
# 67  Sagittal T2/STIR             Spinal Canal Stenosis  L3/L4  Normal/Mild             1621
# 68  Sagittal T2/STIR             Spinal Canal Stenosis  L3/L4       Severe              122
# 69  Sagittal T2/STIR             Spinal Canal Stenosis  L4/L5     Moderate              237
# 70  Sagittal T2/STIR             Spinal Canal Stenosis  L4/L5  Normal/Mild             1481
# 71  Sagittal T2/STIR             Spinal Canal Stenosis  L4/L5       Severe              254
# 72  Sagittal T2/STIR             Spinal Canal Stenosis  L5/S1     Moderate               51
# 73  Sagittal T2/STIR             Spinal Canal Stenosis  L5/S1  Normal/Mild             1900
# 74  Sagittal T2/STIR             Spinal Canal Stenosis  L5/S1       Severe               19

# %%
from sklearn.model_selection import KFold

skf = KFold(n_splits=N_FOLDS, shuffle=True, random_state=SEED)
fold_score = []
study_ids = np.array(train_merged.study_id.unique())

df_train = pd.DataFrame()
df_valid = pd.DataFrame()

for fold, (trn_idx, val_idx) in enumerate(skf.split(range(len(study_ids)))):
    print("train size", len(trn_idx), "test size", len(val_idx))
    trx_study_id = study_ids[trn_idx]
    val_study_id = study_ids[val_idx]

    df_train = train_merged.loc[train_merged.study_id.isin(trx_study_id)]
    df_valid = train_merged.loc[train_merged.study_id.isin(val_study_id)]
    break
# Out:
# train size 1833 test size 141

# %%
df_train[["plane", "condition", "level", "instance_number", "label"]].groupby(["plane", "condition", "level", "label"]).count().reset_index()
# Out:
#                plane                   condition  level        label  \
# 0           Axial T2  Left Subarticular Stenosis  L1/L2     Moderate
# 1           Axial T2  Left Subarticular Stenosis  L1/L2  Normal/Mild
# 2           Axial T2  Left Subarticular Stenosis  L1/L2       Severe
# 3           Axial T2  Left Subarticular Stenosis  L2/L3     Moderate
# 4           Axial T2  Left Subarticular Stenosis  L2/L3  Normal/Mild
# ..               ...                         ...    ...          ...
# 70  Sagittal T2/STIR       Spinal Canal Stenosis  L4/L5  Normal/Mild
# 71  Sagittal T2/STIR       Spinal Canal Stenosis  L4/L5       Severe
# 72  Sagittal T2/STIR       Spinal Canal Stenosis  L5/S1     Moderate
# 73  Sagittal T2/STIR       Spinal Canal Stenosis  L5/S1  Normal/Mild
# 74  Sagittal T2/STIR       Spinal Canal Stenosis  L5/S1       Severe
#
#     instance_number
# 0                86
# 1              1573
# 2                21
# 3               239
# 4              1443
# ..              ...
# 70             1379
# 71              228
# 72               44
# 73             1767
# 74               18
#
# [75 rows x 5 columns]

# %%
df_valid[["plane", "condition", "level", "instance_number", "label"]].groupby(["plane", "condition", "level", "label"]).count().reset_index()
# Out:
#                plane                   condition  level        label  \
# 0           Axial T2  Left Subarticular Stenosis  L1/L2     Moderate
# 1           Axial T2  Left Subarticular Stenosis  L1/L2  Normal/Mild
# 2           Axial T2  Left Subarticular Stenosis  L1/L2       Severe
# 3           Axial T2  Left Subarticular Stenosis  L2/L3     Moderate
# 4           Axial T2  Left Subarticular Stenosis  L2/L3  Normal/Mild
# ..               ...                         ...    ...          ...
# 68  Sagittal T2/STIR       Spinal Canal Stenosis  L4/L5  Normal/Mild
# 69  Sagittal T2/STIR       Spinal Canal Stenosis  L4/L5       Severe
# 70  Sagittal T2/STIR       Spinal Canal Stenosis  L5/S1     Moderate
# 71  Sagittal T2/STIR       Spinal Canal Stenosis  L5/S1  Normal/Mild
# 72  Sagittal T2/STIR       Spinal Canal Stenosis  L5/S1       Severe
#
#     instance_number
# 0                 7
# 1               115
# 2                 7
# 3                15
# 4               111
# ..              ...
# 68              102
# 69               26
# 70                7
# 71              133
# 72                1
#
# [73 rows x 5 columns]
